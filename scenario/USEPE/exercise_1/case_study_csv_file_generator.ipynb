# %% [markdown]
# # This notebook generates the data defining the case study

# %% [markdown]
# A .csv file is created containing:
#  - Origin
#  - Destination
#  - Departure time
#  - Type of drone
#
# for each drone forming the background traffic and delivery drones traffic.

# %%
"""
We define a default path where the modules developed in USEPE are stored
"""

default_path = r"C:\workspace3\bluesky"

"""
We define a second default path where the scenarios are stored
"""

default_path2 = r"C:\workspace3\scenarios-exercise1\scenario\USEPE\exercise_1"

# %%
import os
import sys
import configparser
import pickle
import osmnx as ox
import random
import pandas as pd
import datetime

os.chdir(default_path)
from usepe.city_model.utils import read_my_graphml, layersDict
from usepe.city_model.multi_di_graph_3D import MultiDiGrpah3D
from usepe.city_model.city_graph import cityGraph
from usepe.city_model.scenario_definition import createDeliveryCSV, createBackgroundTrafficCSV, createScenarioCSV

# %% [markdown]
# Configuration file¶
#
# We create a config file with the following fields:
#
# [City]
#
# mode = rectangle
#
# #hannover_lat = 52.376
#
# #hannover_lon = 9.76
#
# #zone_size = 1000
#
# hannover_lat_min = 52.297839999994714
#
# hannover_lat_max = 52.438260000005286
#
# hannover_lon_min = 9.643080000001035
#
# hannover_lon_max = 9.844349999998968
#
# import = True
#
# imported_graph_path = ./data/exercise_1_reference.graphml
#
# [Layers]
# number_of_layers = 9
#
# layer_width = 25
#
# [BuildingData]
#
# lat_min = 52.297839999994714
#
# lat_max = 52.438260000005286
#
# lon_min = 9.643080000001035
#
# lon_max = 9.844349999998968
#
# divisions = 20
#
# directory_hannover = C:\workspace3\bluesky_usepe_git\usepe\city_model\data\CityGML_LoD1
#
# [Options]
#
# one_way = False
#
# simplify = True
#
# simplification_distance = 0
#
# simplification_error = 2
#
# [Outputs]
#
# graph_path = ./data/exercise_1_reference.graphml
#
# [Segments]
#
# import = True
#
# path = ./data/reference_segments.pkl
#
# [Corridors]
#
# corridors =
#
# altitude = 250
#
# delta_z = 25
#
# speed = 50
#
# acceleration_length = 50
#
# file_path_corridors = ./data/usepe-hannover-corridors.geojson
#
# [Strategic_Deconfliction]
#
# ratio = 3
#
# delay = 60

# %%
 # -------------- 1. CONFIGURATION FILE -----------------
"""
This section reads the configuration file.
Change the config_path to read the desired file
"""
# CONFIG
config_path = default_path2 + r"\settings_exercise_1_reference.cfg"
config = configparser.ConfigParser()
config.read( config_path )
# Out:
# ['C:\\workspace3\\scenarios-exercise1\\scenario\\USEPE\\exercise_1\\settings_exercise_1_reference.cfg']

# %%
# -------------- 2. CITY GRAPH -------------------------
"""
This section creates a city graph or loads the graph defined with the city section of the
configuration file.
"""
# City
os.chdir(default_path2)
if config['City'].getboolean( 'import' ):
    filepath = config['City']['imported_graph_path']
    G = read_my_graphml( filepath )
    G = MultiDiGrpah3D( G )
    # fig, ax = ox.plot_graph( G )
else:
    print('Check the path to the graph file')
    G = cityGraph( config )
# Out:
# Reading the graph...

# %%
# -------------- 3. SEGMENTS ----------------------------
"""
This section creates a airspace segmentation or loads the segmentation defined with the segment
section of the configuration file.
Comment it to neglect the segmentation
"""
os.chdir(default_path2)
if config['Segments'].getboolean( 'import' ):
    path = config['Segments']['path']
    with open( path, 'rb' ) as f:
        segments = pickle.load( f )
else:
    segments = None

# %% [markdown]
# # Data for the experiments
#
# The densities to be tested in the experiments are
#  - Low: 0.0964 simultaneous flights / km^2
#  - Medium: 0.964 simultaneous flights / km^2
#  - High: 9.64 simultaneous flights / km^2
#
# The average flight duration calculated is: 2384 s
#
# The simulation time considered is: 2h (7200 s)

# %%
# General
simulation_time = 7200

# Background traffic
density = {'Low': 0.0964, 'Medium': 0.964, 'High': 9.64}
avg_flight_duration = 544

# Delivery
departure_times = [1800,1800,1800]
frequencies = [None, 1000, None]

#createScenarioCSV(density['Low'], avg_flight_duration, departure_times, frequencies, simulation_time, G, config )
# Add background traffic
print('Creating background traffic...')
createBackgroundTrafficCSV(density['Low'], avg_flight_duration, simulation_time, G, segments, config)

# Add operation scenario (delivery)
print('Creating delivery drones...')
#createDeliveryCSV(departure_times, frequencies, simulation_time)
# Out:
# Creating background traffic...
# Creating flight 1...
# Creating flight 2...
# Creating flight 3...
# Creating flight 4...
# Creating flight 5...
# Creating flight 6...
# Creating flight 7...
# Creating flight 8...
# Creating flight 9...
# Creating flight 10...
# Creating flight 11...
# Creating flight 12...
# Creating flight 13...
# Creating flight 14...
# Creating flight 15...
# Creating flight 16...
# Creating flight 17...
# Creating flight 18...
# Creating flight 19...
# Creating flight 20...
# Creating flight 21...
# Creating flight 22...
# Creating flight 23...
# Creating flight 24...
# Creating flight 25...
# Creating flight 26...
# Creating flight 27...
# Creating flight 28...
# Creating flight 29...
# Point in no fly zone: lat 52.43637214169721, lon 9.786487011414817
# Creating flight 30...
# Creating flight 31...
# Point in no fly zone: lat 52.43202567169733, lon 9.78303286209259
# Creating flight 32...
# Creating flight 33...
# Creating flight 34...
# Creating flight 35...
# Creating flight 36...
# Creating flight 37...
# Creating flight 38...
# Creating flight 39...
# Creating flight 40...
# Creating flight 41...
# Creating flight 42...
# Creating flight 43...
# Creating flight 44...
# Creating flight 45...
# Creating flight 46...
# Creating flight 47...
# Creating flight 48...
# Creating flight 49...
# Creating flight 50...
# Creating flight 51...
# Creating flight 52...
# Creating flight 53...
# Creating flight 54...
# Creating flight 55...
# Creating flight 56...
# Creating flight 57...
# Creating flight 58...
# Creating flight 59...
# Creating flight 60...
# Creating flight 61...
# Point in no fly zone: lat 52.429968078328784, lon 9.784083952868375
# Creating flight 62...
# Creating flight 63...
# Creating flight 64...
# Creating flight 65...
# Creating flight 66...
# Creating flight 67...
# Creating flight 68...
# Creating flight 69...
# Creating flight 70...
# Creating flight 71...
# Point in no fly zone: lat 52.43663844257136, lon 9.762187363468259
# Creating flight 72...
# Creating flight 73...
# Creating flight 74...
# Creating flight 75...
# Creating flight 76...
# Creating flight 77...
# Creating flight 78...
# Creating flight 79...
# Creating flight 80...
# Creating flight 81...
# Creating flight 82...
# Creating flight 83...
# Creating flight 84...
# Creating flight 85...
# Creating flight 86...
# Creating flight 87...
# Creating flight 88...
# Creating flight 89...
# Creating flight 90...
# Creating flight 91...
# Creating flight 92...
# Creating flight 93...
# Creating flight 94...
# Creating flight 95...
# Creating flight 96...
# Creating flight 97...
# Creating flight 98...
# Creating flight 99...
# Creating flight 100...
# Creating flight 101...
# Creating flight 102...
# Creating flight 103...
# Creating flight 104...
# Creating flight 105...
# Creating flight 106...
# Creating flight 107...
# Creating flight 108...
# Creating flight 109...
# Creating flight 110...
# Creating flight 111...
# Creating flight 112...
# Creating flight 113...
# Creating flight 114...
# Creating flight 115...
# Creating flight 116...
# Creating flight 117...
# Point in no fly zone: lat 52.42270705810175, lon 9.734792523421735
# Creating flight 118...
# Creating flight 119...
# Creating flight 120...
# Creating flight 121...
# Point in no fly zone: lat 52.42566667824344, lon 9.732681350701041
# Creating flight 122...
# Creating flight 123...
# Creating flight 124...
# Creating flight 125...
# Creating flight 126...
# Creating flight 127...
# Creating flight 128...
# Creating flight 129...
# Creating flight 130...
# Creating flight 131...
# Creating flight 132...
# Creating flight 133...
# Creating flight 134...
# Creating flight 135...
# Creating flight 136...
# Creating flight 137...
# Creating flight 138...
# Creating flight 139...
# Creating flight 140...
# Creating flight 141...
# Creating flight 142...
# Creating flight 143...
# Point in no fly zone: lat 52.41520590329849, lon 9.78518480395301
# Creating flight 144...
# Creating flight 145...
# Creating flight 146...
# Creating flight 147...
# Creating flight 148...
# Creating flight 149...
# Creating flight 150...
# Creating flight 151...
# Creating flight 152...
# Creating flight 153...
# Point in no fly zone: lat 52.42115274365498, lon 9.736159971093786
# Creating flight 154...
# Point in no fly zone: lat 52.43705865906459, lon 9.774238554190179
# Creating flight 155...
# Creating flight 156...
# Creating flight 157...
# Creating flight 158...
# Creating flight 159...
# Creating flight 160...
# Creating flight 161...
# Creating flight 162...
# Creating flight 163...
# Creating flight 164...
# Creating flight 165...
# Creating flight 166...
# Creating flight 167...
# Creating flight 168...
# Creating flight 169...
# Creating flight 170...
# Creating flight 171...
# Creating flight 172...
# Creating flight 173...
# Creating flight 174...
# Creating flight 175...
# Creating flight 176...
# Creating flight 177...
# Creating flight 178...
# Point in no fly zone: lat 52.43224696063323, lon 9.772462241779923
# Creating flight 179...
# Creating flight 180...
# Creating flight 181...
# Creating flight 182...
# Point in no fly zone: lat 52.43353399790083, lon 9.763109243421356
# Creating flight 183...
# Creating flight 184...
# Creating flight 185...
# Creating flight 186...
# Creating flight 187...
# Creating flight 188...
# Creating flight 189...
# Creating flight 190...
# Creating flight 191...
# Creating flight 192...
# Creating flight 193...
# Creating flight 194...
# Creating flight 195...
# Creating flight 196...
# Creating flight 197...
# Creating flight 198...
# Creating flight 199...
# Creating flight 200...
# Point in no fly zone: lat 52.4257263263504, lon 9.737109378205721
# Creating flight 201...
# Creating flight 202...
# Creating flight 203...
# Creating flight 204...
# Creating flight 205...
# Creating flight 206...
# Creating flight 207...
# Creating flight 208...
# Creating flight 209...
# Creating flight 210...
# Creating flight 211...
# Creating flight 212...
# Creating flight 213...
# Creating flight 214...
# Creating flight 215...
# Creating flight 216...
# Creating flight 217...
# Creating flight 218...
# Creating flight 219...
# Creating flight 220...
# Creating flight 221...
# Creating flight 222...
# Creating flight 223...
# Creating flight 224...
# Point in no fly zone: lat 52.42633403104993, lon 9.73350073642018
# Creating flight 225...
# Creating flight 226...
# Creating flight 227...
# Creating flight 228...
# Creating flight 229...
# Creating flight 230...
# Creating flight 231...
# Creating flight 232...
# Creating flight 233...
# Creating flight 234...
# Creating flight 235...
# Creating flight 236...
# Creating flight 237...
# Creating flight 238...
# Creating flight 239...
# Creating flight 240...
# Point in no fly zone: lat 52.41539335495917, lon 9.794295156825825
# Creating flight 241...
# Creating flight 242...
# Creating flight 243...
# Creating flight 244...
# Creating flight 245...
# Creating flight 246...
# Creating flight 247...
# Creating flight 248...
# Creating flight 249...
# Creating flight 250...
# Creating flight 251...
# Creating flight 252...
# Creating flight 253...
# Point in no fly zone: lat 52.41902464697802, lon 9.787286369966194
# Creating flight 254...
# Creating flight 255...
# Creating flight 256...
# Creating flight 257...
# Creating flight 258...
# Creating flight 259...
# Creating flight 260...
# Creating flight 261...
# Creating flight 262...
# Creating flight 263...
# Creating flight 264...
# Creating flight 265...
# Creating flight 266...
# Creating flight 267...
# Creating flight 268...
# Creating flight 269...
# Creating flight 270...
# Creating flight 271...
# Point in no fly zone: lat 52.42134417604273, lon 9.789103568551344
# Creating flight 272...
# Background traffic stored in : C:\workspace3\scenarios-exercise1\scenario\USEPE\exercise_1\data\background_traffic_0-0964_544_7200.csv
# Creating delivery drones...
